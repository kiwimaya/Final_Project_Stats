# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Stations = pd.read_csv("stations.csv")
Stations
# Out:
#     Unnamed: 0  empty_slots  \
# 0            0           14
# 1            1           22
# 2            2            9
# 3            3           13
# 4            4           29
# 5            5            9
# 6            6            6
# 7            7           18
# 8            8           21
# 9            9           11
# 10          10           11
#
#                                                 extra  free_bikes  \
# 0   {'address': '400 1st Ave S', 'last_updated': 1...           0
# 1   {'address': '1811 University Drive N', 'last_u...           0
# 2   {'address': 'NP Ave & 5th St N', 'last_updated...           0
# 3   {'address': '650 NP Ave N', 'last_updated': 15...           0
# 4   {'address': '1401 Administrative Ave', 'last_u...           1
# 5   {'address': '425 Broadway N', 'last_updated': ...           2
# 6   {'address': '811 Broadway', 'last_updated': 15...           2
# 7   {'address': '811 2nd Ave N', 'last_updated': 1...           0
# ...

# %%
Stations.shape
# Out:
# (11, 9)

# %%
YMCA_4R = pd.read_csv("4RYMCA.csv")

# %%
YMCA_4R['Site']='YMCA'

# %%
YMCA_4R = YMCA_4R.iloc[:,1:]
YMCA_4R
# Out:
#    distance                          name  Site
# 0       191                  Rhombus Guys  YMCA
# 1       250                        Pounds  YMCA
# 2       363             NoBull Smokehouse  YMCA
# 3       370         Nichole's Fine Pastry  YMCA
# 4       399  Ishtar Mediterranean Cuisine  YMCA
# 5       435               Würst Bier Hall  YMCA
# 6       436                      JL Beers  YMCA
# 7       440                    Vinyl Taco  YMCA
# 8       448               Mexican Village  YMCA
# 9       504                        Subway  YMCA

# %%
Downtown_4R = pd.read_csv("4RDowntown.csv")

# %%
Downtown_4R['Site']='Downtown'
Downtown_4R
# Out:
#    Unnamed: 0  distance                          name      Site
# 0           0       172                      JL Beers  Downtown
# 1           1       179                    Vinyl Taco  Downtown
# 2           2       188  Ishtar Mediterranean Cuisine  Downtown
# 3           3       199             NoBull Smokehouse  Downtown
# 4           4       229                        Pounds  Downtown
# 5           5       242                        Subway  Downtown
# 6           6       245                     Taco Shop  Downtown
# 7           7       248               Würst Bier Hall  Downtown
# 8           8       269         84 Italian Steakhouse  Downtown
# 9           9       276                  Rhombus Guys  Downtown

# %%
Downtown_4R = Downtown_4R.iloc[:,1:]
Downtown_4R
# Out:
#    distance                          name      Site
# 0       172                      JL Beers  Downtown
# 1       179                    Vinyl Taco  Downtown
# 2       188  Ishtar Mediterranean Cuisine  Downtown
# 3       199             NoBull Smokehouse  Downtown
# 4       229                        Pounds  Downtown
# 5       242                        Subway  Downtown
# 6       245                     Taco Shop  Downtown
# 7       248               Würst Bier Hall  Downtown
# 8       269         84 Italian Steakhouse  Downtown
# 9       276                  Rhombus Guys  Downtown

# %%
Hall_4R =pd.read_csv("4RHall.csv")

# %%
Hall_4R['Site']='Hall'
Hall_4R
# Out:
#    Unnamed: 0  distance                          name  Site
# 0           0       134             NoBull Smokehouse  Hall
# 1           1       141               Würst Bier Hall  Hall
# 2           2       155                        Pounds  Hall
# 3           3       176  Ishtar Mediterranean Cuisine  Hall
# 4           4       207               Mexican Village  Hall
# 5           5       217                  Rhombus Guys  Hall
# 6           6       228         Nichole's Fine Pastry  Hall
# 7           7       248                    Vinyl Taco  Hall
# 8           8       254                      JL Beers  Hall
# 9           9       257   46 North Pints & Provisions  Hall

# %%
Hall_4R = Hall_4R.iloc[:,1:]
Hall_4R
# Out:
#    distance                          name  Site
# 0       134             NoBull Smokehouse  Hall
# 1       141               Würst Bier Hall  Hall
# 2       155                        Pounds  Hall
# 3       176  Ishtar Mediterranean Cuisine  Hall
# 4       207               Mexican Village  Hall
# 5       217                  Rhombus Guys  Hall
# 6       228         Nichole's Fine Pastry  Hall
# 7       248                    Vinyl Taco  Hall
# 8       254                      JL Beers  Hall
# 9       257   46 North Pints & Provisions  Hall

# %%
Village_4R = pd.read_csv("4RVillage.csv")

# %%
Village_4R['Site']='Village'
Village_4R
# Out:
#    Unnamed: 0  distance                         name     Site
# 0           0       230       Chipotle Mexican Grill  Village
# 1           1       254  Grand Junction Grilled Subs  Village
# 2           2       280            Papa John's Pizza  Village
# 3           3       341                   Red Pepper  Village
# 4           4       348         Little Caesars Pizza  Village
# 5           5       364               Domino's Pizza  Village
# 6           6       391                       Subway  Village
# 7           7       446           Buffalo Wild Wings  Village
# 8           8       524                   Applebee's  Village
# 9           9      1406                 Jimmy John's  Village

# %%
Village_4R = Village_4R.iloc[:,1:]
Village_4R
# Out:
#    distance                         name     Site
# 0       230       Chipotle Mexican Grill  Village
# 1       254  Grand Junction Grilled Subs  Village
# 2       280            Papa John's Pizza  Village
# 3       341                   Red Pepper  Village
# 4       348         Little Caesars Pizza  Village
# 5       364               Domino's Pizza  Village
# 6       391                       Subway  Village
# 7       446           Buffalo Wild Wings  Village
# 8       524                   Applebee's  Village
# 9      1406                 Jimmy John's  Village

# %%
all_4R =pd.concat([Village_4R,Hall_4R,Downtown_4R,YMCA_4R],ignore_index=True)

# %%
all_4R['web']='4Sq'
all_4R
# Out:
#     distance                          name      Site  web
# 0        230        Chipotle Mexican Grill   Village  4Sq
# 1        254   Grand Junction Grilled Subs   Village  4Sq
# 2        280             Papa John's Pizza   Village  4Sq
# 3        341                    Red Pepper   Village  4Sq
# 4        348          Little Caesars Pizza   Village  4Sq
# 5        364                Domino's Pizza   Village  4Sq
# 6        391                        Subway   Village  4Sq
# 7        446            Buffalo Wild Wings   Village  4Sq
# 8        524                    Applebee's   Village  4Sq
# 9       1406                  Jimmy John's   Village  4Sq
# 10       134             NoBull Smokehouse      Hall  4Sq
# 11       141               Würst Bier Hall      Hall  4Sq
# 12       155                        Pounds      Hall  4Sq
# 13       176  Ishtar Mediterranean Cuisine      Hall  4Sq
# 14       207               Mexican Village      Hall  4Sq
# ...

# %%
YMCA_RY= pd.read_csv("YRYMCA.csv")

# %%
YMCA_RY['Site']='YMCA'

# %%
YMCA_RY = YMCA_RY.iloc[:,1:]
YMCA_RY
# Out:
#        name  Site
# 0  Circle W  YMCA

# %%
Downtown_RY = pd.read_csv("YRDowntown.csv")

# %%
Downtown_RY['Site']='Downtown'

# %%
Downtown_RY = Downtown_RY.iloc[:,1:]
Downtown_RY
# Out:
#        name      Site
# 0  Circle W  Downtown

# %%
Hall_RY = pd.read_csv("YRHall.csv")

# %%
Hall_RY['Site']='Hall'

# %%
Hall_RY = Hall_RY.iloc[:,1:]
Hall_RY
# Out:
#                                name  Site
# 0                Swannee River Cafe  Hall
# 1  Little Joey's Italian Restaurant  Hall
# 2         Suwannee River Outfitters  Hall

# %%
Village_RY = pd.read_csv("YRVillage.csv")

# %%
Village_RY['Site']='Village'

# %%
Village_RY = Village_RY.iloc[:,1:]
Village_RY
# Out:
#                                name     Site
# 0                Swannee River Cafe  Village
# 1  Little Joey's Italian Restaurant  Village
# 2         Suwannee River Outfitters  Village

# %%
all_RY =pd.concat([Village_RY,Hall_RY,Downtown_RY,YMCA_RY],ignore_index=True)
all_RY
# Out:
#                                name      Site
# 0                Swannee River Cafe   Village
# 1  Little Joey's Italian Restaurant   Village
# 2         Suwannee River Outfitters   Village
# 3                Swannee River Cafe      Hall
# 4  Little Joey's Italian Restaurant      Hall
# 5         Suwannee River Outfitters      Hall
# 6                          Circle W  Downtown
# 7                          Circle W      YMCA

# %%
all_RY['web']='YELP'
all_RY
# Out:
#                                name      Site   web
# 0                Swannee River Cafe   Village  YELP
# 1  Little Joey's Italian Restaurant   Village  YELP
# 2         Suwannee River Outfitters   Village  YELP
# 3                Swannee River Cafe      Hall  YELP
# 4  Little Joey's Italian Restaurant      Hall  YELP
# 5         Suwannee River Outfitters      Hall  YELP
# 6                          Circle W  Downtown  YELP
# 7                          Circle W      YMCA  YELP

# %%
plt.hist(all_RY['Site'], bins=32)
plt.grid(True)
plt.title('Restaurants near bike sations per Yelp')
plt.show()

# %%
plt.hist(all_4R['Site'], bins=32)
plt.grid(True)
plt.title('Restaurants near bike sations per Four Sq')
plt.show()
