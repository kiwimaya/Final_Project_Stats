# %%
import requests
import os
import json
import pandas as pd

# %%
api_key = 'Bearer ' + os.environ['YELP']

# %%
url = 'https://api.yelp.com/v3/businesses/search'

# %%
params = {
  	"location": "Fargo",
  	"ll": "46.90244,-96.7978",
  	"term": "Shopping Mall",
    "radius": "4000",
    "locale":"en_US"
    
}

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

# %%
response = requests.request("GET", url, params =params, headers=headers)

print(response.text)
# Out:
# {"businesses": [{"id": "-KXkLu9pg-07eFNTATS7iw", "alias": "west-acres-fargo-2", "name": "West Acres", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/UrZUUcpEeD4BySDwD4Y6HA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/west-acres-fargo-2?adjust_creative=J5h1CC8CMU8IXoLGgPFmjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=J5h1CC8CMU8IXoLGgPFmjA", "review_count": 32, "categories": [{"alias": "shoppingcenters", "title": "Shopping Centers"}], "rating": 3.5, "coordinates": {"latitude": 46.85924743408117, "longitude": -96.84672008220892}, "transactions": [], "price": "$$", "location": {"address1": "3902 13th Ave S", "address2": "Ste 3717", "address3": "", "city": "Fargo", "zip_code": "58103", "country": "US", "state": "ND", "display_address": ["3902 13th Ave S", "Ste 3717", "Fargo, ND 58103"]}, "phone": "+17012822222", "display_phone": "(701) 282-2222", "distance": 2631.416540426541}, {"id": "rDwaPDpB9K22d1t9jIf15Q", "alias": "minn-dak-market-fargo", "name": "Minn Dak Market", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/sHW5st2_d9myaYAtDGvJnQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/minn-dak-market-fargo?adjust_creative=J5h1CC8CMU8IXoLGgPFmjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=J5h1CC8CMU8IXoLGgPFmjA", "review_count": 2, "categories": [{"alias": "gourmet", "title": "Specialty Food"}, {"alias": "giftshops", "title": "Gift Shops"}, {"alias": "popupshops", "title": "Pop-up Shops"}], "rating": 5.0, "coordinates": {"latitude": 46.85873937046532, "longitude": -96.84794685201211}, "transactions": [], "location": {"address1": "3902 13th Ave S", "address2": "", "address3": null, "city": "Fargo", "zip_code": "58103", "country": "US", "state": "ND", "display_address": ["3902 13th Ave S", "Fargo, ND 58103"]}, "phone": "+17015321371", "display_phone": "(701) 532-1371", "distance": 2636.6256525458098}, {"id": "vkD-WKYKSadDnkYTkjdNyA", "alias": "tj-maxx-fargo", "name": "TJ Maxx", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/1UE8MpyawhRXViQBptrGKQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/tj-maxx-fargo?adjust_creative=J5h1CC8CMU8IXoLGgPFmjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=J5h1CC8CMU8IXoLGgPFmjA", "review_count": 6, "categories": [{"alias": "deptstores", "title": "Department Stores"}], "rating": 2.5, "coordinates": {"latitude": 46.860033, "longitude": -96.856822}, "transactions": [], "price": "$$", "location": {"address1": "4340 13th Ave S", "address2": "", "address3": "", "city": "Fargo", "zip_code": "58103", "country": "US", "state": "ND", "display_address": ["4340 13th Ave S", "Fargo, ND 58103"]}, "phone": "+17012771435", "display_phone": "(701) 277-1435", "distance": 3151.1600632955747}, {"id": "__oqHM41E1bPLUv4fbMhBw", "alias": "unclaimed-freight-furniture-fargo", "name": "Unclaimed Freight Furniture", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/4MRldk_YBX8fn6xLqhm0dg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/unclaimed-freight-furniture-fargo?adjust_creative=J5h1CC8CMU8IXoLGgPFmjA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=J5h1CC8CMU8IXoLGgPFmjA", "review_count": 17, "categories": [{"alias": "furniture", "title": "Furniture Stores"}, {"alias": "mattresses", "title": "Mattresses"}, {"alias": "rugs", "title": "Rugs"}], "rating": 2.5, "coordinates": {"latitude": 46.84144, "longitude": -96.79753}, "transactions": [], "price": "$", "location": {"address1": "2520 South University Dr", "address2": null, "address3": null, "city": "Fargo", "zip_code": "58103", "country": "US", "state": "ND", "display_address": ["2520 South University Dr", "Fargo, ND 58103"]}, "phone": "+17012373360", "display_phone": "(701) 237-3360", "distance": 2304.755564475566}, {"id": "16woz5FcJ8g3PNGnEexA3w", "alias": "macys-fargo", "name": "Macy's", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/jZfeBpid9nTEM7fCfJoCPQ/o.jpg", "is_closed": false,  ...

# %%
response
# Out:
# <Response [200]>

# %%
json_object = json.dumps(response.json(), indent=4)
 
with open("YRsample.json", "w") as outfile:
    outfile.write(json_object)

# %%
with open('YRsample.json', 'r') as f:
  data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
data1 = data['businesses']

# %%
pd.json_normalize(data1)
# Out:
#                         id                              alias  \
# 0   -KXkLu9pg-07eFNTATS7iw                 west-acres-fargo-2
# 1   rDwaPDpB9K22d1t9jIf15Q              minn-dak-market-fargo
# 2   vkD-WKYKSadDnkYTkjdNyA                      tj-maxx-fargo
# 3   __oqHM41E1bPLUv4fbMhBw  unclaimed-freight-furniture-fargo
# 4   16woz5FcJ8g3PNGnEexA3w                        macys-fargo
# 5   iEXh4Qa6akiK3Tu1ZPCqJA                     jcpenney-fargo
# 6   kHJwKXlb6nsKsEtIaWkrMg               comic-junction-fargo
# 7   qcwOKVOp9ZZtGYiIuALs7g           evereve-west-acres-fargo
# 8   j8KKn0FQ9BqrYbpo2izP6g                       target-fargo
# 9   uVeqYwkriEHnn9YpL52Lpw             mills-fleet-farm-fargo
# 10  WmkeVP_zsQsKX90Rj0QC-w  almost-famous-body-piercing-fargo
# 11  zb-F588Zq41aib1qEOux0w                 burlington-fargo-2
# 12  6hCiSIHxO-yKQ0EIhoL8DA                  kohls-fargo-fargo
# 13  wqSMR68H0PhWVKOtBha92Q                  dollar-tree-fargo
# 14  gEMar9mf10ulwWbggt04Pg                       chicos-fargo
# 15  WiQ6Gnyuwfzmog-TUWdUsA          platos-closet-fargo-fargo
# 16  puszzIEyIU6Okqz2c44-zQ       big-nicks-sports-cards-fargo
# 17  eyMER9IkZHvZY_lP0YfOeg             classic-jewelers-fargo
# 18  YlQer8guky4IfgXqWZh10A                   forever-21-fargo
# 19  juvBSsP09Fe_lZGJdbIpWw     shirt-shop-in-the-mall-fargo-2
#
#                            name  \
# 0                    West Acres
# 1               Minn Dak Market
# 2                       TJ Maxx
# 3   Unclaimed Freight Furniture
# 4                        Macy's
# 5                      JCPenney
# 6                Comic Junction
# 7          EVEREVE - West Acres
# 8                        Target
# 9              Mills Fleet Farm
# 10  Almost Famous Body Piercing
# 11                   Burlington
# 12                       Kohl's
# 13                  Dollar Tree
# 14                      Chico's
# 15         Plato's Closet Fargo
# 16       Big Nicks Sports Cards
# 17             Classic Jewelers
# 18                   Forever 21
# 19       Shirt Shop In The Mall
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/UrZUUc...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/sHW5st...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/1UE8Mp...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/4MRldk...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/jZfeBp...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/D4B1sM...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/IA31WB...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/6O5bHA...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/IFso72...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/L8B__l...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/5WlQWu...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/fb5loy...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/yWklXN...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/5yVeHx...      False
# 14                                                         False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/sMdHGB...      False
# 16                                                         False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/9nGtPj...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/mM-7j5...      False
# 19                                                         False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/west-acres-fargo-2?ad...            32
# 1   https://www.yelp.com/biz/minn-dak-market-fargo...             2
# 2   https://www.yelp.com/biz/tj-maxx-fargo?adjust_...             6
# 3   https://www.yelp.com/biz/unclaimed-freight-fur...            17
# 4   https://www.yelp.com/biz/macys-fargo?adjust_cr...             5
# 5   https://www.yelp.com/biz/jcpenney-fargo?adjust...             4
# 6   https://www.yelp.com/biz/comic-junction-fargo?...            10
# 7   https://www.yelp.com/biz/evereve-west-acres-fa...             2
# 8   https://www.yelp.com/biz/target-fargo?adjust_c...            14
# 9   https://www.yelp.com/biz/mills-fleet-farm-farg...            20
# 10  https://www.yelp.com/biz/almost-famous-body-pi...            22
# 11  https://www.yelp.com/biz/burlington-fargo-2?ad...             5
# 12  https://www.yelp.com/biz/kohls-fargo-fargo?adj...             3
# 13  https://www.yelp.com/biz/dollar-tree-fargo?adj...             6
# 14  https://www.yelp.com/biz/chicos-fargo?adjust_c...             1
# 15  https://www.yelp.com/biz/platos-closet-fargo-f...            11
# 16  https://www.yelp.com/biz/big-nicks-sports-card...             5
# 17  https://www.yelp.com/biz/classic-jewelers-farg...             3
# 18  https://www.yelp.com/biz/forever-21-fargo?adju...             1
# 19  https://www.yelp.com/biz/shirt-shop-in-the-mal...             4
#
#                                            categories  rating transactions  \
# 0   [{'alias': 'shoppingcenters', 'title': 'Shoppi...     3.5           []
# 1   [{'alias': 'gourmet', 'title': 'Specialty Food...     5.0           []
# 2   [{'alias': 'deptstores', 'title': 'Department ...     2.5           []
# 3   [{'alias': 'furniture', 'title': 'Furniture St...     2.5           []
# 4   [{'alias': 'deptstores', 'title': 'Department ...     2.0           []
# 5   [{'alias': 'deptstores', 'title': 'Department ...     2.5           []
# 6   [{'alias': 'comicbooks', 'title': 'Comic Books...     4.5           []
# 7   [{'alias': 'womenscloth', 'title': 'Women's Cl...     4.5           []
# 8   [{'alias': 'deptstores', 'title': 'Department ...     3.0           []
# 9   [{'alias': 'deptstores', 'title': 'Department ...     2.5           []
# 10  [{'alias': 'jewelry', 'title': 'Jewelry'}, {'a...     2.5           []
# 11  [{'alias': 'deptstores', 'title': 'Department ...     2.0           []
# 12  [{'alias': 'deptstores', 'title': 'Department ...     3.0           []
# 13  [{'alias': 'discountstore', 'title': 'Discount...     2.0           []
# 14  [{'alias': 'womenscloth', 'title': 'Women's Cl...     5.0           []
# 15  [{'alias': 'vintage', 'title': 'Used, Vintage ...     1.0           []
# 16  [{'alias': 'hobbyshops', 'title': 'Hobby Shops'}]     3.5           []
# 17  [{'alias': 'jewelry', 'title': 'Jewelry'}, {'a...     1.0           []
# 18  [{'alias': 'accessories', 'title': 'Accessorie...     1.0           []
# 19  [{'alias': 'menscloth', 'title': 'Men's Clothi...     1.0           []
#
#     ... coordinates.latitude coordinates.longitude         location.address1  \
# 0   ...            46.859247            -96.846720           3902 13th Ave S
# 1   ...            46.858739            -96.847947           3902 13th Ave S
# 2   ...            46.860033            -96.856822           4340 13th Ave S
# 3   ...            46.841440            -96.797530  2520 South University Dr
# 4   ...            46.858599            -96.846541           3902 13th Ave S
# 5   ...            46.857045            -96.848175          3902 13th Ave SW
# 6   ...            46.854699            -96.798787      1621 S University Dr
# 7   ...            46.859747            -96.848217           3902 13th Ave S
# 8   ...            46.860024            -96.852095          4202 13th Ave SW
# 9   ...            46.822605            -96.835670            3730 36th St S
# 10  ...            46.859007            -96.846668           3902 13th Ave S
# 11  ...            46.863052            -96.854698           4305 13th Ave S
# 12  ...            46.860280            -96.861050           4444 13th Ave S
# 13  ...            46.863270            -96.860540           4427 13th Ave S
# 14  ...            46.859182            -96.846907           3902 13th Ave S
# 15  ...            46.841022            -96.863258            2551 45th St S
# 16  ...            46.859450            -96.845990           3902 13th Ave S
# 17  ...            46.861100            -96.854620           4302 13th Ave S
# 18  ...            46.859508            -96.845691           1629 13th Ave S
# 19  ...            46.859450            -96.845990           3902 13th Ave S
#
#     location.address2                    location.address3  location.city  \
# 0            Ste 3717                                               Fargo
# 1                                                     None          Fargo
# 2                                                                   Fargo
# 3                None                                 None          Fargo
# 4            Ste 2500                      West Acres Mall          Fargo
# 5             Ste 200                                 None          Fargo
# 6                                                                   Fargo
# 7                                          West Acres Mall          Fargo
# 8                                                                   Fargo
# 9                                                                   Fargo
# 10            Ste 213                                               Fargo
# 11               None                                 None          Fargo
# 12                                                                  Fargo
# 13              Ste 3                                 None          Fargo
# 14           Ste 2325           West Acres Shopping Center          Fargo
# 15                                                                  Fargo
# 16                                                                  Fargo
# 17             Ste 19                                               Fargo
# 18           Ste 1629                                 None          Fargo
# 19                     West Acres Regional Shopping Center          Fargo
#
#    location.zip_code location.country location.state  \
# 0              58103               US             ND
# 1              58103               US             ND
# 2              58103               US             ND
# 3              58103               US             ND
# 4              58103               US             ND
# 5              58103               US             ND
# 6              58103               US             ND
# 7              58103               US             ND
# 8              58103               US             ND
# 9              58104               US             ND
# 10             58103               US             ND
# 11             58103               US             ND
# 12             58103               US             ND
# 13             58103               US             ND
# 14             58103               US             ND
# 15             58104               US             ND
# 16             58103               US             ND
# 17             58103               US             ND
# 18             58103               US             ND
# 19             58103               US             ND
#
#                              location.display_address
# 0        [3902 13th Ave S, Ste 3717, Fargo, ND 58103]
# 1                  [3902 13th Ave S, Fargo, ND 58103]
# 2                  [4340 13th Ave S, Fargo, ND 58103]
# 3         [2520 South University Dr, Fargo, ND 58103]
# 4   [3902 13th Ave S, Ste 2500, West Acres Mall, F...
# 5        [3902 13th Ave SW, Ste 200, Fargo, ND 58103]
# 6             [1621 S University Dr, Fargo, ND 58103]
# 7   [3902 13th Ave S, West Acres Mall, Fargo, ND 5...
# 8                 [4202 13th Ave SW, Fargo, ND 58103]
# 9                   [3730 36th St S, Fargo, ND 58104]
# 10        [3902 13th Ave S, Ste 213, Fargo, ND 58103]
# 11                 [4305 13th Ave S, Fargo, ND 58103]
# 12                 [4444 13th Ave S, Fargo, ND 58103]
# 13          [4427 13th Ave S, Ste 3, Fargo, ND 58103]
# 14  [3902 13th Ave S, Ste 2325, West Acres Shoppin...
# 15                  [2551 45th St S, Fargo, ND 58104]
# 16                 [3902 13th Ave S, Fargo, ND 58103]
# 17         [4302 13th Ave S, Ste 19, Fargo, ND 58103]
# 18       [1629 13th Ave S, Ste 1629, Fargo, ND 58103]
# 19  [3902 13th Ave S, West Acres Regional Shopping...
#
# [20 rows x 24 columns]

# %%
df = pd.DataFrame(data1)

# %%
S5_Village = df.filter(['name'])
S5_Village
# Out:
#                            name
# 0                    West Acres
# 1               Minn Dak Market
# 2                       TJ Maxx
# 3   Unclaimed Freight Furniture
# 4                        Macy's
# 5                      JCPenney
# 6                Comic Junction
# 7          EVEREVE - West Acres
# 8                        Target
# 9              Mills Fleet Farm
# 10  Almost Famous Body Piercing
# 11                   Burlington
# 12                       Kohl's
# 13                  Dollar Tree
# 14                      Chico's
# 15         Plato's Closet Fargo
# 16       Big Nicks Sports Cards
# 17             Classic Jewelers
# 18                   Forever 21
# 19       Shirt Shop In The Mall

# %%
S5_Village.to_csv('YSVillage.csv')
